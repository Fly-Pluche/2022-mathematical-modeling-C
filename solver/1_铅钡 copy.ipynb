# %%
import pandas as pd
import numpy as np

# %%
data_origin =pd.read_excel('excel//extract//1//铅钡归一化.xlsx')
print(data_origin)
data = data_origin.loc[:,'二氧化硅(SiO2)_归一化':'量化风化']
data.head()
data
# Out:
#     二氧化硅(SiO2)_归一化  氧化钠(Na2O)_归一化  氧化钾(K2O)_归一化  氧化钙(CaO)_归一化  氧化镁(MgO)_归一化  \
# 0         0.019046       0.000339      0.098027      0.022855      0.034453
# 1         0.010573       0.002164      0.000686      0.014455      0.000506
# 2         0.002420       0.021297      0.007808      0.031157      0.004738
# 3         0.017633       0.015048      0.019605      0.034282      0.020730
# 4         0.015560       0.006347      0.004988      0.028617      0.017226
# 5         0.010389       0.002159      0.000711      0.014064      0.000518
# 6         0.001953       0.001398      0.037344      0.029399      0.000323
# 7         0.018783       0.008500      0.023340      0.007618      0.004994
# 8         0.020773       0.037608      0.013070      0.003614      0.004516
# 9         0.017287       0.023378      0.005684      0.006642      0.003962
# 10        0.013780       0.003290      0.003437      0.010841      0.002937
# ...

# %%
氧化钠(Na2O)_归一化=0.034-0.366 × 二氧化硅(SiO2)_归一化-0.113 × 氧化钾(K2O)_归一化-0.238 × 氧化钙(CaO)_归一化＋0.231 × 氧化镁(MgO)_归一化-0.066 × 氧化铝(Al2O3)_归一化-0.108 × 氧化铁(Fe2O3)_归一化-0.037 × 氧化铜(CuO)_归一化-0.666 × 氧化铅(PbO)_归一化-0.131 × 氧化钡(BaO)_归一化-0.188 × 五氧化二磷(P2O5)_归一化＋0.072 × 氧化锶(SrO)_归一化＋0.009 × 氧化锡(SnO2)_归一化＋0.028 × 二氧化硫(SO2)_归一化＋0.013 × 表面风化
氧化钡(BaO)_归一化=0.047-0.582 × 氧化铅(PbO)_归一化-0.671 × 二氧化硅(SiO2)_归一化-0.019 × 氧化钠(Na2O)_归一化＋0.043 × 氧化钾(K2O)_归一化-0.091 × 氧化钙(CaO)_归一化-0.107 × 氧化镁(MgO)_归一化-0.1 × 氧化铝(Al2O3)_归一化-0.033 × 氧化铁(Fe2O3)_归一化＋0.233 × 氧化铜(CuO)_归一化-0.101 × 五氧化二磷(P2O5)_归一化＋0.023 × 氧化锶(SrO)_归一化＋0.046 × 氧化锡(SnO2)_归一化＋0.12 × 二氧化硫(SO2)_归一化-0.001 × 表面风化
氧化铁(Fe2O3)_归一化=0.004-0.041 × 二氧化硅(SiO2)_归一化-0.138 × 氧化铝(Al2O3)_归一化-0.077 × 氧化钠(Na2O)_归一化＋0.29 × 氧化钾(K2O)_归一化＋0.45 × 氧化钙(CaO)_归一化-0.008 × 氧化镁(MgO)_归一化-0.058 × 氧化铜(CuO)_归一化-0.306 × 氧化铅(PbO)_归一化-0.173 × 氧化钡(BaO)_归一化＋0.12 × 五氧化二磷(P2O5)_归一化-0.001 × 氧化锶(SrO)_归一化＋0.137 × 氧化锡(SnO2)_归一化-0.08 × 二氧化硫(SO2)_归一化＋0.01 × 表面风化
氧化钾(K2O)_归一化=-0.001-0.344 × 二氧化硅(SiO2)_归一化-0.078 × 氧化钠(Na2O)_归一化＋0.097 × 氧化钙(CaO)_归一化＋0.238 × 氧化镁(MgO)_归一化＋0.247 × 氧化铝(Al2O3)_归一化＋0.283 × 氧化铁(Fe2O3)_归一化-0.104 × 氧化铜(CuO)_归一化＋0.121 × 氧化铅(PbO)_归一化＋0.216 × 氧化钡(BaO)_归一化-0.083 × 五氧化二磷(P2O5)_归一化-0.172 × 氧化锶(SrO)_归一化-0.058 × 氧化锡(SnO2)_归一化＋0.025 × 二氧化硫(SO2)_归一化＋0.009 × 表面风化
氧化镁(MgO)_归一化=0.013＋0.055 × 二氧化硅(SiO2)_归一化＋0.272 × 氧化钙(CaO)_归一化＋0.064 × 氧化钠(Na2O)_归一化＋0.094 × 氧化钾(K2O)_归一化＋0.136 × 氧化铝(Al2O3)_归一化-0.004 × 氧化铁(Fe2O3)_归一化-0.062 × 氧化铜(CuO)_归一化-0.239 × 氧化铅(PbO)_归一化-0.218 × 氧化钡(BaO)_归一化＋0.136 × 五氧化二磷(P2O5)_归一化＋0.149 × 氧化锶(SrO)_归一化＋0.066 × 氧化锡(SnO2)_归一化-0.062 × 二氧化硫(SO2)_归一化-0.001 × 表面风化
氧化锶(SrO)_归一化=-0.0-0.46 × 二氧化硅(SiO2)_归一化＋0.067 × 五氧化二磷(P2O5)_归一化＋0.017 × 氧化钠(Na2O)_归一化-0.058 × 氧化钾(K2O)_归一化-0.104 × 氧化钙(CaO)_归一化＋0.126 × 氧化镁(MgO)_归一化＋0.093 × 氧化铝(Al2O3)_归一化-0.001 × 氧化铁(Fe2O3)_归一化＋0.075 × 氧化铜(CuO)_归一化＋0.648 × 氧化铅(PbO)_归一化＋0.041 × 氧化钡(BaO)_归一化＋0.009 × 氧化锡(SnO2)_归一化＋0.041 × 二氧化硫(SO2)_归一化＋0.007 × 表面风化
二氧化硫(SO2)_归一化=0.054-0.867 × 二氧化硅(SiO2)_归一化-0.042 × 氧化锡(SnO2)_归一化＋0.04 × 氧化钠(Na2O)_归一化＋0.051 × 氧化钾(K2O)_归一化＋0.366 × 氧化钙(CaO)_归一化-0.32 × 氧化镁(MgO)_归一化-0.25 × 氧化铝(Al2O3)_归一化-0.159 × 氧化铁(Fe2O3)_归一化-0.517 × 氧化铜(CuO)_归一化-1.359 × 氧化铅(PbO)_归一化＋1.243 × 氧化钡(BaO)_归一化＋0.169 × 五氧化二磷(P2O5)_归一化＋0.249 × 氧化锶(SrO)_归一化-0.004 × 表面风化
五氧化二磷(P2O5)_归一化=0.069-0.801 × 二氧化硅(SiO2)_归一化-0.338 × 氧化钡(BaO)_归一化-0.088 × 氧化钠(Na2O)_归一化-0.056 × 氧化钾(K2O)_归一化＋0.295 × 氧化钙(CaO)_归一化＋0.233 × 氧化镁(MgO)_归一化-0.052 × 氧化铝(Al2O3)_归一化＋0.079 × 氧化铁(Fe2O3)_归一化＋0.047 × 氧化铜(CuO)_归一化-0.721 × 氧化铅(PbO)_归一化＋0.134 × 氧化锶(SrO)_归一化-0.128 × 氧化锡(SnO2)_归一化＋0.056 × 二氧化硫(SO2)_归一化-0.014 × 表面风化
氧化钙(CaO)_归一化=0.021-0.558 × 二氧化硅(SiO2)_归一化＋0.027 × 氧化钾(K2O)_归一化-0.047 × 氧化钠(Na2O)_归一化＋0.194 × 氧化镁(MgO)_归一化＋0.129 × 氧化铝(Al2O3)_归一化＋0.124 × 氧化铁(Fe2O3)_归一化＋0.04 × 氧化铜(CuO)_归一化＋0.156 × 氧化铅(PbO)_归一化-0.129 × 氧化钡(BaO)_归一化＋0.123 × 五氧化二磷(P2O5)_归一化-0.089 × 氧化锶(SrO)_归一化＋0.038 × 氧化锡(SnO2)_归一化＋0.051 × 二氧化硫(SO2)_归一化-0.001 × 表面风化
氧化铅(PbO)_归一化=0.046-0.058 × 氧化铜(CuO)_归一化-0.472 × 二氧化硅(SiO2)_归一化-0.027 × 氧化钠(Na2O)_归一化＋0.007 × 氧化钾(K2O)_归一化＋0.032 × 氧化钙(CaO)_归一化-0.034 × 氧化镁(MgO)_归一化-0.129 × 氧化铝(Al2O3)_归一化-0.017 × 氧化铁(Fe2O3)_归一化-0.164 × 氧化钡(BaO)_归一化-0.06 × 五氧化二磷(P2O5)_归一化＋0.11 × 氧化锶(SrO)_归一化-0.019 × 氧化锡(SnO2)_归一化-0.038 × 二氧化硫(SO2)_归一化-0.005 × 表面风化
氧化铜(CuO)_归一化=0.038-0.496 × 二氧化硅(SiO2)_归一化-0.045 × 氧化铁(Fe2O3)_归一化-0.02 × 氧化钠(Na2O)_归一化-0.084 × 氧化钾(K2O)_归一化＋0.114 × 氧化钙(CaO)_归一化-0.125 × 氧化镁(MgO)_归一化-0.059 × 氧化铝(Al2O3)_归一化-0.827 × 氧化铅(PbO)_归一化＋0.953 × 氧化钡(BaO)_归一化＋0.056 × 五氧化二磷(P2O5)_归一化＋0.179 × 氧化锶(SrO)_归一化-0.145 × 氧化锡(SnO2)_归一化-0.205 × 二氧化硫(SO2)_归一化-0.002 × 表面风化
氧化铝(Al2O3)_归一化=0.036＋0.07 × 二氧化硅(SiO2)_归一化＋0.129 × 氧化镁(MgO)_归一化-0.018 × 氧化钠(Na2O)_归一化＋0.093 × 氧化钾(K2O)_归一化＋0.171 × 氧化钙(CaO)_归一化-0.051 × 氧化铁(Fe2O3)_归一化-0.027 × 氧化铜(CuO)_归一化-0.857 × 氧化铅(PbO)_归一化-0.191 × 氧化钡(BaO)_归一化-0.03 × 五氧化二磷(P2O5)_归一化＋0.106 × 氧化锶(SrO)_归一化＋0.143 × 氧化锡(SnO2)_归一化-0.046 × 二氧化硫(SO2)_归一化-0.003 × 表面风化
氧化锡(SnO2)_归一化=0.027＋0.086 × 二氧化硅(SiO2)_归一化＋0.035 × 氧化锶(SrO)_归一化＋0.008 × 氧化钠(Na2O)_归一化-0.073 × 氧化钾(K2O)_归一化＋0.168 × 氧化钙(CaO)_归一化＋0.211 × 氧化镁(MgO)_归一化＋0.482 × 氧化铝(Al2O3)_归一化＋0.168 × 氧化铁(Fe2O3)_归一化-0.226 × 氧化铜(CuO)_归一化-0.406 × 氧化铅(PbO)_归一化＋0.292 × 氧化钡(BaO)_归一化-0.238 × 五氧化二磷(P2O5)_归一化-0.026 × 二氧化硫(SO2)_归一化-0.011 × 表面风化
二氧化硅(SiO2)_归一化=0.033-0.014 × 氧化钠(Na2O)_归一化-0.018 × 氧化钾(K2O)_归一化-0.105 × 氧化钙(CaO)_归一化＋0.008 × 氧化镁(MgO)_归一化＋0.011 × 氧化铝(Al2O3)_归一化-0.002 × 氧化铁(Fe2O3)_归一化-0.033 × 氧化铜(CuO)_归一化-0.444 × 氧化铅(PbO)_归一化-0.177 × 氧化钡(BaO)_归一化-0.063 × 五氧化二磷(P2O5)_归一化-0.072 × 氧化锶(SrO)_归一化＋0.004 × 氧化锡(SnO2)_归一化-0.023 × 二氧化硫(SO2)_归一化＋0.004 × 表面风化
